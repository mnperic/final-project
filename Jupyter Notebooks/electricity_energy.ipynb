# %%
# Import dependencies and setup

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as matplotlib
import matplotlib.dates as matplotlibdates
import matplotlib.dates as mdates
# import datetime
# from matplotlib.dates import date2num

# %%
# Read each dataset and store as DataFrame

elec_gen_fuel_type_state_path = "Resources/electricity_generation_fuel_type_state_territory.csv"
elec_gen_fuel_type_state_df = pd.read_csv(elec_gen_fuel_type_state_path)

elec_gen_fuel_type_path = "Resources/electricity_generation_fuel_type.csv"
elec_gen_fuel_type_df = pd.read_csv(elec_gen_fuel_type_path)

elec_gen_sector_path = "Resources/electricity_generation_sector_state_territory.csv"
elec_gen_sector_df = pd.read_csv(elec_gen_sector_path)

energy_use_state_path = "Resources/energy_use_state_territory.csv"
energy_use_state_df = pd.read_csv(energy_use_state_path)

energy_balance_path = "Resources/energy_balance.csv"
energy_balance_df = pd.read_csv(energy_balance_path)

energy_CIP_path = "Resources/energy_consumption_intensity_productivity.csv"
energy_CIP_df = pd.read_csv(energy_CIP_path)

exports_path = "Resources/exports_2019-2020.csv"
exports_df = pd.read_csv(exports_path)

fossil_fuels_path = "Resources/fossil_fuels.csv"
fossil_fuels_df = pd.read_csv(fossil_fuels_path)

imports_path = "Resources/imports_2019-2020.csv"
imports_df = pd.read_csv(imports_path)

renewables_path = "Resources/renewables.csv"
renewables_df = pd.read_csv(renewables_path)

# %%
# Preview elec_gen_fuel_type_state_df

elec_gen_fuel_type_state_df.head()
elec_gen_fuel_type_state_df = elec_gen_fuel_type_state_df.dropna(axis=1, how='all')
elec_gen_fuel_type_state_df.head()
# Out:
#   State    Coal Natural Gas    Oil  Hydro Other Renewables
# 0   NSW  75.60%       2.80%  0.50%  3.50%           17.70%
# 1   VIC  67.70%       4.50%  0.40%  4.90%           22.50%
# 2   QLD  66.50%      16.30%  1.40%  0.90%           14.90%
# 3    WA  21.10%      61.70%  5.30%  0.40%           11.50%
# 4    SA   0.00%      40.80%  1.00%  0.10%           58.10%

# %%
# Preview elec_gen_fuel_type_df

elec_gen_fuel_type_df.head()
elec_gen_fuel_type_df = elec_gen_fuel_type_df.dropna(axis=1, how='all')
elec_gen_fuel_type_df.head()
# Out:
#       Year  Black Coal  Brown Coal  Natural Gas  Renewables  Other
# 0  1994–95        59.3        20.7          8.6         9.8    1.6
# 1  1999–00        59.0        23.9          7.7         8.5    0.8
# 2  2004–05        55.9        23.3         10.4         8.9    1.4
# 3  2009–10        49.0        22.2         17.7         8.6    2.4
# 4  2014–15        42.6        20.2         21.0        13.5    2.7

# %%
# Preview elec_sector_df

elec_gen_sector_df.head()
# Out:
#   State Electricity Sector Mining and Manufacturing Other Industries
# 0   NSW                94%                       1%               5%
# 1   VIC                92%                       2%               6%
# 2   QLD                87%                       6%               7%
# 3    WA                57%                      39%               5%
# 4    SA                85%                       3%              12%

# %%
# Preview energy_use_state_df

energy_use_state_df
energy_use_state_df = energy_use_state_df.dropna()
energy_use_state_df
# Out:
#   State   Coal    Oil    Gas Renewables
# 0   NSW  42.1%  43.3%   8.6%       5.9%
# 1   VIC  34.1%  38.5%  21.8%       5.5%
# 2   QLD  35.9%  37.2%  18.9%       8.0%
# 3    WA  10.1%  34.8%  53.0%       2.1%
# 4    SA   8.2%  44.0%  35.6%      12.2%
# 5   TAS   9.3%  38.4%   9.3%      43.0%
# 6    NT   0.0%  33.6%  65.6%       0.8%
# 7   AUS  29.1%  38.8%  25.7%       6.4%

# %%
# Preview energy_balance_df

energy_balance_df.head()
# Out:
#       Year  Production  Consumption  Net Exports  Yearly Total
# 0  1979–80      3802.7       3131.4        803.7        7737.8
# 1  1980–81      4193.8       3146.3        937.3        8277.4
# 2  1981–82      4380.8       3237.6        922.2        8540.6
# 3  1982–83      4552.8       3122.7       1208.1        8883.6
# 4  1983–84      4911.2       3221.2       1712.1        9844.5

# %%
# Preview energy_CIP_df

energy_CIP_df.head()
energy_CIP_df = energy_CIP_df.dropna(axis=1, how='all')
energy_CIP_df.head()
# Out:
#       Year  GDP  Energy Consumption  Energy Intensity  Energy Productivity
# 0  1979–80  100                 100               100                  100
# 1  1980–81  103                 101                97                  103
# 2  1981–82  107                 103                97                  103
# 3  1982–83  104                 100                96                  105
# 4  1983–84  109                 103                94                  106

# %%
# Preview exports_df

exports_df.head()
# Out:
#             Source  Amount (PJ)
# 0             Coal        11088
# 1      Natural Gas         4393
# 2    Crude Oil/ORF          626
# 3              LPG          141
# 4  Refind Products           42

# %%
# Preview fossil_fuels_df

fossil_fuels_df.head()
# Out:
#       Year    Coal     Oil    Gas  Renewables  Yearly Totals
# 0  1974–75   981.1  1327.7  189.2       204.0         2498.0
# 1  1975–76   981.2  1339.7  211.2       206.2         2532.1
# 2  1976–77  1047.7  1410.6  256.2       199.3         2714.5
# 3  1977–78  1070.4  1438.3  283.0       201.2         2791.7
# 4  1978–79  1103.0  1440.9  314.9       199.6         2858.8

# %%
# Preview imports_df

imports_df.head()
# Out:
#                  Source  Amount (PJ)
# 0      Refined Products         1328
# 1         Crude Oil/ORF          696
# 2           Natural Gas          180
# 3                   LPG           21
# 4  Coal and by-products           19

# %%
# Preview renewables_df

renewables_df.head()
# Out:
#       Year  Hydro  Wind  Bioenergy  Solar  Yearly Totals
# 0  1994–95  16239     7        723     19          16988
# 1  1995–96  15731     7        928     23          16689
# 2  1996–97  16852     7        965     28          17852
# 3  1997–98  15733     8       1029     34          16804
# 4  1998–99  16563    28       1133     38          17762

# %%
# Statistical analysis – energy_balance_df
# Calculate 'Production' total

energy_balance_prod_total = energy_balance_df['Production'].sum()
energy_balance_prod_total
# Out:
# 433338.49999999994

# %%
# Calculate 'Consumption' total

energy_balance_cons_total = energy_balance_df['Consumption'].sum()
energy_balance_cons_total
# Out:
# 196544.8

# %%
# Calculate 'Net Exports' total

energy_balance_net_exports_total = energy_balance_df['Net Exports'].sum()
energy_balance_net_exports_total
# Out:
# 237592.09999999998

# %%
# Calculate cumulative totals and add to DataFrame

energy_balance_df['Production Cumulative'] = energy_balance_df['Production'].cumsum()
energy_balance_df['Consumption Cumulative'] = energy_balance_df['Consumption'].cumsum()
energy_balance_df['Net Exports Cumulative'] = energy_balance_df['Net Exports'].cumsum()
energy_balance_df.head()
# Out:
#       Year  Production  Consumption  Net Exports  Yearly Total  \
# 0  1979–80      3802.7       3131.4        803.7        7737.8
# 1  1980–81      4193.8       3146.3        937.3        8277.4
# 2  1981–82      4380.8       3237.6        922.2        8540.6
# 3  1982–83      4552.8       3122.7       1208.1        8883.6
# 4  1983–84      4911.2       3221.2       1712.1        9844.5
#
#    Production Cumulative  Consumption Cumulative  Net Exports Cumulative
# 0                 3802.7                  3131.4                   803.7
# 1                 7996.5                  6277.7                  1741.0
# 2                12377.3                  9515.3                  2663.2
# 3                16930.1                 12638.0                  3871.3
# 4                21841.3                 15859.2                  5583.4

# %%
# Statistical analysis – exports_balance_df
# Calculate 'Amount (PJ)' total

exports_amount_total = exports_df['Amount (PJ)'].sum() - 16290
exports_amount_total
# Out:
# 0

# %%
# Statistical analysis – fossil_fuels_df
# Calculate 'Coal' total

fossil_fuels_coal_totals = fossil_fuels_df['Coal'].sum()
fossil_fuels_coal_totals
# Out:
# 79134.6

# %%
# Calculate 'Oil' total

fossil_fuels_coal_totals = fossil_fuels_df['Oil'].sum()
fossil_fuels_coal_totals
# Out:
# 79530.6

# %%
# Calculate 'Gas' total

fossil_fuels_gas_totals = fossil_fuels_df['Gas'].sum()
fossil_fuels_gas_totals
# Out:
# 40142.4

# %%
# Calculate 'Renewables' total

fossil_fuels_renewables_totals = fossil_fuels_df['Renewables'].sum()
fossil_fuels_renewables_totals
# Out:
# 12223.900000000003

# %%
# Calculate cumulative totals and add to DataFrame

fossil_fuels_df['Coal Cumulative'] = fossil_fuels_df['Coal'].cumsum()
fossil_fuels_df['Oil Cumulative'] = fossil_fuels_df['Oil'].cumsum()
fossil_fuels_df['Gas Cumulative'] = fossil_fuels_df['Gas'].cumsum()
fossil_fuels_df['Renewables Cumulative'] = fossil_fuels_df['Renewables'].cumsum()
fossil_fuels_df.head()
# Out:
#       Year    Coal     Oil    Gas  Renewables  Yearly Totals  Coal Cumulative  \
# 0  1974–75   981.1  1327.7  189.2       204.0         2498.0            981.1
# 1  1975–76   981.2  1339.7  211.2       206.2         2532.1           1962.3
# 2  1976–77  1047.7  1410.6  256.2       199.3         2714.5           3010.0
# 3  1977–78  1070.4  1438.3  283.0       201.2         2791.7           4080.4
# 4  1978–79  1103.0  1440.9  314.9       199.6         2858.8           5183.4
#
#    Oil Cumulative  Gas Cumulative  Renewables Cumulative
# 0          1327.7           189.2                  204.0
# 1          2667.4           400.4                  410.2
# 2          4078.0           656.6                  609.5
# 3          5516.3           939.6                  810.7
# 4          6957.2          1254.5                 1010.3

# %%
# Statistical analysis – imports_balance_df
# Calculate 'Amount (PJ)' total

imports_amount_total = imports_df['Amount (PJ)'].sum()
imports_amount_total
# Out:
# 2244

# %%
# Statistical analysis – renewables_balance_df
# Calculate 'Hydro' total

renewables_hydro_total = renewables_df['Hydro'].sum()
renewables_hydro_total
# Out:
# 407046

# %%
# Calculate 'Wind' total

renewables_wind_total = renewables_df['Wind'].sum()
renewables_wind_total
# Out:
# 140088

# %%
# Calculate 'Bioenergy' total

renewables_bioenergy_total = renewables_df['Bioenergy'].sum()
renewables_bioenergy_total
# Out:
# 65791

# %%
# Calculate 'Solar' total

renewables_solar_total = renewables_df['Solar'].sum()
renewables_solar_total
# Out:
# 79988

# %%
# Calculate cumulative totals and add to DataFrame

renewables_df['Hydro Cumulative'] = renewables_df['Hydro'].cumsum()
renewables_df['Wind Cumulative'] = renewables_df['Wind'].cumsum()
renewables_df['Bioenergy Cumulative'] = renewables_df['Bioenergy'].cumsum()
renewables_df['Solar Cumulative'] = renewables_df['Solar'].cumsum()
renewables_df.head()
# Out:
#       Year  Hydro  Wind  Bioenergy  Solar  Yearly Totals  Hydro Cumulative  \
# 0  1994–95  16239     7        723     19          16988             16239
# 1  1995–96  15731     7        928     23          16689             31970
# 2  1996–97  16852     7        965     28          17852             48822
# 3  1997–98  15733     8       1029     34          16804             64555
# 4  1998–99  16563    28       1133     38          17762             81118
#
#    Wind Cumulative  Bioenergy Cumulative  Solar Cumulative
# 0                7                   723                19
# 1               14                  1651                42
# 2               21                  2616                70
# 3               29                  3645               104
# 4               57                  4778               142

# %%
## Plot elec_gen_fuel_type_state_df (bar graph)
# Preview
elec_gen_fuel_type_state_df
# Out:
#   State    Coal Natural Gas     Oil   Hydro Other Renewables
# 0   NSW  75.60%       2.80%   0.50%   3.50%           17.70%
# 1   VIC  67.70%       4.50%   0.40%   4.90%           22.50%
# 2   QLD  66.50%      16.30%   1.40%   0.90%           14.90%
# 3    WA  21.10%      61.70%   5.30%   0.40%           11.50%
# 4    SA   0.00%      40.80%   1.00%   0.10%           58.10%
# 5   TAS   0.00%       1.70%   0.20%  82.10%           16.00%
# 6    NT   0.00%      85.30%  10.00%   0.00%            4.60%
# 7   AUS  53.90%      20.00%   1.70%   5.60%           18.80%

# %%
# Plot elec_gen_fuel_type_state_df

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Data
plotdata = pd.DataFrame({
    "Coal":[75.6, 67.7, 66.5, 21.1, 0, 0, 0, 53.9],
    "Natural Gas":[2.8, 4.5, 16.3, 61.7, 40.8, 1.7, 85.3, 20.0],
    "Oil":[0.5, 0.4, 1.4, 5.3, 1.0, 0.2, 10.0, 1.7],
    "Hydro":[3.5, 4.9, 0.9, 0.4, 0.1, 82.1, 0, 5.6],
    "Other Renewables":[17.7, 22.5, 14.9, 11.5, 58.1, 16.0, 4.6, 18.8],
    }, 
    index=elec_fuel_df['State'])

# Figure
plotdata.plot(figsize=(15,5), kind="bar", stacked=True, alpha=0.9,
             ).legend(
            loc='upper right', ncol=1, title="Fuel Type")

# Titles
plt.title("Electricity generation by fuel-type, 2019-20", fontdict = font_1)
plt.xlabel("State", fontdict = font_2)
plt.ylabel("Percent", fontdict = font_2)

# Style
matplotlib.style.use('default')

# Grid
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', 
                       alpha=0.1, linestyle='--', linewidth=1)

# Aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show/save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/australian-energy/Images/elec_gen_fuel_type_state.png", 
            transparent=False, dpi=300)
plt.show()

# %%
# Plot elec_gen_fuel_type_df (line graph)
# Preview
elec_gen_fuel_type_df
# Out:
#       Year  Black Coal  Brown Coal  Natural Gas  Renewables  Other
# 0  1994–95        59.3        20.7          8.6         9.8    1.6
# 1  1999–00        59.0        23.9          7.7         8.5    0.8
# 2  2004–05        55.9        23.3         10.4         8.9    1.4
# 3  2009–10        49.0        22.2         17.7         8.6    2.4
# 4  2014–15        42.6        20.2         21.0        13.5    2.7
# 5  2019–20        42.2        12.7         20.8        22.6    1.7
# 6     2020        41.0        12.9         20.0        24.4    1.7

# %%
# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Data
plotdata_1 = pd.DataFrame({
    "Black Coal":[59.3, 59.0, 55.9, 49.0, 42.6, 42.2, 41.0],
    "Brown Coal":[20.7, 23.9, 23.3, 22.2, 20.2, 12.7, 12.9],
    "Natural Gas":[8.6, 7.7, 10.4, 17.7, 21.0, 20.8, 20.0],
    "Renewables":[9.8, 8.5, 8.9, 8.6, 13.5, 22.6, 24.4],
    "Other":[1.6, 0.8, 1.4, 2.4, 2.7, 1.7, 1.7],
    }, 
    index=elec_gen_fuel_type_df['Year'])

# Figure
plotdata_1_stacked = plotdata_1.apply(lambda x: x*100/sum(x), axis=1)
plotdata_1_stacked.plot(figsize=(15,5), kind="bar", stacked=True, alpha=0.9,
             ).legend(
            loc='upper right', ncol=1, title="Fuel-type")

plt.title("Electricity generation by fuel-type, 1994–2020", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Percent", fontdict = font_2)

# Style
matplotlib.style.use('default')

# Grid
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', 
                       alpha=0.1, linestyle='--', linewidth=1)

# Aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show/save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/australian-energy/Images/elec_gen_fuel_type.png", 
            transparent=False, dpi=300)
plt.show()

# %%
# Plot elec_gen_sector_df
# Preview
elec_gen_sector_df
# Out:
#   State Electricity Sector Mining and Manufacturing Other Industries
# 0   NSW                94%                       1%               5%
# 1   VIC                92%                       2%               6%
# 2   QLD                87%                       6%               7%
# 3    WA                57%                      39%               5%
# 4    SA                85%                       3%              12%
# 5   TAS                98%                       1%               2%
# 6    NT                45%                      52%               3%
# 7   AUS                84%                      10%               6%

# %%
# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Data
plotdata_2 = pd.DataFrame({
    "Electricity":[94, 92, 87, 57, 85, 98, 45, 84],
    "Mining/Manufacturing":[1, 2, 6, 39, 3, 1, 52, 10],
    "Other Industries inc. Residential Solar":[5, 6, 7, 5, 12, 2, 3, 6],
    }, 
    index=elec_gen_sector_df['State'])

# Figure
plotdata_2.plot(figsize=(15,5), kind="bar", stacked=True, alpha=0.9,
             ).legend(
            loc='upper right', ncol=1, title="Sector")

plt.title("Electricity generation by sector", fontdict = font_1)
plt.xlabel("State", fontdict = font_2)
plt.ylabel("Percent", fontdict = font_2)

# Stylea
matplotlib.style.use('default')

# Grid
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', 
                       alpha=0.1, linestyle='--', linewidth=1)

# Aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show/save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/australian-energy/Images/elec_gen_sector.png", 
            transparent=False, dpi=300)
plt.show()

# %%
# Plot energy_use_state_df (bar graph)
# Preview
energy_use_state_df
# Out:
#   State   Coal    Oil    Gas Renewables
# 0   NSW  42.1%  43.3%   8.6%       5.9%
# 1   VIC  34.1%  38.5%  21.8%       5.5%
# 2   QLD  35.9%  37.2%  18.9%       8.0%
# 3    WA  10.1%  34.8%  53.0%       2.1%
# 4    SA   8.2%  44.0%  35.6%      12.2%
# 5   TAS   9.3%  38.4%   9.3%      43.0%
# 6    NT   0.0%  33.6%  65.6%       0.8%
# 7   AUS  29.1%  38.8%  25.7%       6.4%

# %%
# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Data
plotdata_3 = pd.DataFrame({
    "Coal":[42.1, 34.1, 35.9, 10.1, 8.2, 9.3, 0.0, 29.1],
    "Oil":[43.3, 38.5, 37.2, 34.8, 44.0, 38.4, 33.6, 38.8],
    "Gas":[8.6, 21.8, 18.9, 53.0, 35.6, 9.3, 65.6, 25.7],
    "Renewables":[5.9, 5.5, 8.0, 2.1, 12.2, 43.0, 0.8, 6.4]
    
    }, 
    index=energy_use_state_df['State'])

# Figure
plotdata_3.plot(figsize=(15,5), kind="bar", stacked=True, alpha=0.9,
             ).legend(
            loc='upper right', ncol=1, title="Fuel Type")

plt.title("Energy use by fuel-type, 2019–20", fontdict = font_1)
plt.xlabel("State", fontdict = font_2)
plt.ylabel("Percent", fontdict = font_2)

# Style
matplotlib.style.use('default')

# Grid
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', 
                       alpha=0.1, linestyle='--', linewidth=1)

# Aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show/save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/australian-energy/Images/energy_use_state.png", 
            transparent=False, dpi=300)
plt.show()

# %%
# Plot energy_balance_df (bar graph)
# Preview
energy_balance_df.head()
# Out:
#       Year  Production  Consumption  Net Exports  Yearly Total  \
# 0  1979–80      3802.7       3131.4        803.7        7737.8
# 1  1980–81      4193.8       3146.3        937.3        8277.4
# 2  1981–82      4380.8       3237.6        922.2        8540.6
# 3  1982–83      4552.8       3122.7       1208.1        8883.6
# 4  1983–84      4911.2       3221.2       1712.1        9844.5
#
#    Production Cumulative  Consumption Cumulative  Net Exports Cumulative
# 0                 3802.7                  3131.4                   803.7
# 1                 7996.5                  6277.7                  1741.0
# 2                12377.3                  9515.3                  2663.2
# 3                16930.1                 12638.0                  3871.3
# 4                21841.3                 15859.2                  5583.4

# %%
# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Data
plotdata_4 = pd.DataFrame({
    "Production":[3802.7, 4193.8, 4380.8, 4552.8, 4911.2, 5558.9, 6015.3, 6435.1, 6127.6, 6430.2, 7001.4, 7235.5,
                 7587.5, 7705.5, 7752.2, 8351.9, 8438.4, 8898.9, 9549.6, 9413.9, 10131.1, 10729.3, 11055.5,
                 11090.6, 11136.3, 11747.1, 11825.7, 12574.9, 12579.5, 13070.5, 13953.9, 13583.0, 14055.1,
                 15211.6, 16181.9, 16685.6, 17076.9, 17924.1, 18602.7, 19724.8, 20055.3],
    "Consumption":[3131.4, 3146.3, 3237.6, 3122.7, 3221.2, 3370.7, 3402.5, 3514.4, 3623, 3832.7, 3945.9, 3949.9, 
                   3982.7, 4081.8, 4181.9, 4365.4, 4505.5, 4611.1, 4777.6, 4884.7, 4971, 5011.8, 5097.1, 5138.7, 
                   5284.7, 5399.2, 5546.7, 5724, 5736.1, 5843.8, 5823.7, 5902.5, 5888.1, 5915, 5891.1, 5908.6, 6056.2,
                   6120.9, 6187.3, 6195.6, 6013.8],
    "Net Exports":[803.7, 937.31, 922.2, 1208.1, 1712.1, 2377.7, 2576.9, 2641, 2845.3, 2586.1, 2882.1, 3281.2, 3619.2, 
                   3642.7, 3636.5, 3931.1, 3926.6, 4177.5, 4767.9, 4679.3, 5229.4, 5868.1, 5915.5, 6059.5, 6185.6, 
                   6496.7, 6381.2, 6747.1, 6747.7, 7042.2, 8064.8, 7878.6, 8186.8, 9222.6, 10288, 10918.4, 11415.8, 
                   11855.5, 12325.8, 13562.3, 14046]
    }, 
    index=energy_balance_df['Year'])

# Figure
plotdata_4.plot(figsize=(15,5), kind="bar", stacked=True, alpha=0.9,
             ).legend(
            loc='upper right', ncol=1, title="Usage Balance")
plt.plot(energy_balance_df['Year'], energy_balance_df['Yearly Total'], color="red", markersize='3', 
         linewidth=2)

plt.title("Energy balance, 1979–2020", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Petajoules", fontdict = font_2)

# Style
matplotlib.style.use('default')

# Grid
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', 
                       alpha=0.1, linestyle='--', linewidth=1)

# Aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show/save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/australian-energy/Images/energy_balance.png", 
            transparent=False, dpi=300)
plt.show()

# %%
# Plot energy_CIP_df
# Preview
energy_CIP_df.head()
# Out:
#       Year  GDP  Energy Consumption  Energy Intensity  Energy Productivity
# 0  1979–80  100                 100               100                  100
# 1  1980–81  103                 101                97                  103
# 2  1981–82  107                 103                97                  103
# 3  1982–83  104                 100                96                  105
# 4  1983–84  109                 103                94                  106

# %%
# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Data
plt.figure(figsize=(15,5))
plt.plot(energy_CIP_df['Year'], energy_CIP_df['GDP'], color="blue", label='GDP', markersize='7', 
         linewidth=2)
plt.plot(energy_CIP_df['Year'], energy_CIP_df['Energy Consumption'], label='Consumption', color="orange", markersize='7', 
         linewidth=2)
plt.plot(energy_CIP_df['Year'], energy_CIP_df['Energy Intensity'], label='Intensity', color="green", markersize='7', 
         linewidth=2)
plt.plot(energy_CIP_df['Year'], energy_CIP_df['Energy Productivity'], label='Productivity', color="red", 
         markersize='7', linewidth=2)

plt.legend(title='Measure', loc='upper right', ncol=1)

# Ticks
plt.xticks((energy_CIP_df['Year'])[::5
                                ], rotation=25)

plt.title("Energy consumption, intensity and productivity, 1979–2020", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("1979–80 = 100", fontdict = font_2)

# Style
matplotlib.style.use('default')

# Grid
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', 
                       alpha=0.1, linestyle='--', linewidth=1)

# Aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show/save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/australian-energy/Images/energy_CIP.png", 
            transparent=False, dpi=300)
plt.show()

# %%
# Plot exports_df 
# Preview
exports_df
# Out:
#             Source  Amount (PJ)
# 0             Coal        11088
# 1      Natural Gas         4393
# 2    Crude Oil/ORF          626
# 3              LPG          141
# 4  Refind Products           42

# %%
# Plot - Exports

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Figure
plt.figure(figsize=(15,5))
plt.bar(exports_df['Source'], exports_df['Amount (PJ)'], color="blue", 
        width=0.5, alpha=0.5)

# Labels
plt.title('Exports trade, 2019 – 2020', fontdict = font_1)
plt.xlabel('Fuel-type', fontdict = font_2)
plt.ylabel('Petajoules', fontdict = font_2)

# Style
matplotlib.style.use('default')

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', 
                       color='blue', alpha=0.1, dash_capstyle='butt', dash_joinstyle='bevel', 
                       linestyle='--', linewidth=1)
               
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show/save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/australian-energy/Images/exports.png", 
           transparent=False, dpi=300)
plt.show()

# %%
# Plot imports_df 
# Preview
imports_df
# Out:
#                  Source  Amount (PJ)
# 0      Refined Products         1328
# 1         Crude Oil/ORF          696
# 2           Natural Gas          180
# 3                   LPG           21
# 4  Coal and by-products           19

# %%
# Plot - Imports

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Figure
plt.figure(figsize=(15,5))
plt.bar(imports_df['Source'], imports_df['Amount (PJ)'], color="blue", 
        width=0.5, alpha=0.5)

# Labels
plt.title('Imports trade, 2019 – 2020', fontdict = font_1)
plt.xlabel('Fuel-type', fontdict = font_2)
plt.ylabel('Petajoules', fontdict = font_2)

# Style
matplotlib.style.use('default')

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', 
                       color='blue', alpha=0.1, dash_capstyle='butt', dash_joinstyle='bevel', 
                       linestyle='--', linewidth=1)
               
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show/save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/australian-energy/Images/imports.png", 
            transparent=False, dpi=300)
plt.show()

# %%
# Plot fossil_fuels_df
# Preview
fossil_fuels_df.head()
# Out:
#       Year    Coal     Oil    Gas  Renewables  Yearly Totals  Coal Cumulative  \
# 0  1974–75   981.1  1327.7  189.2       204.0         2498.0            981.1
# 1  1975–76   981.2  1339.7  211.2       206.2         2532.1           1962.3
# 2  1976–77  1047.7  1410.6  256.2       199.3         2714.5           3010.0
# 3  1977–78  1070.4  1438.3  283.0       201.2         2791.7           4080.4
# 4  1978–79  1103.0  1440.9  314.9       199.6         2858.8           5183.4
#
#    Oil Cumulative  Gas Cumulative  Renewables Cumulative
# 0          1327.7           189.2                  204.0
# 1          2667.4           400.4                  410.2
# 2          4078.0           656.6                  609.5
# 3          5516.3           939.6                  810.7
# 4          6957.2          1254.5                 1010.3

# %%
# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Data
plt.figure(figsize=(15,5))
plt.plot(fossil_fuels_df['Year'], fossil_fuels_df['Coal Cumulative'], color="blue", label='Coal', markersize='7', 
         linewidth=2)
plt.plot(fossil_fuels_df['Year'], fossil_fuels_df['Oil Cumulative'], color="orange", label='Oil', markersize='7', 
         linewidth=2)
plt.plot(fossil_fuels_df['Year'], fossil_fuels_df['Gas Cumulative'], color="red", label='Gas', markersize='7', 
         linewidth=2)
plt.plot(fossil_fuels_df['Year'], fossil_fuels_df['Renewables Cumulative'], color="green", label='Renewables',
         markersize='7', linewidth=2)


plt.legend(title='Fuel-type', loc='upper right', ncol=1)

# Ticks
plt.xticks((fossil_fuels_df['Year'])[::5
                                ], rotation=25)

plt.title("Cumulative fossil fuel energy use by fuel-type, 1974–2020", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Petajoules", fontdict = font_2)

# Style
matplotlib.style.use('default')

# Grid
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', 
                       alpha=0.1, linestyle='--', linewidth=1)

# Aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show/save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/australian-energy/Images/cumulative_fossil_fuels.png", 
            transparent=False, dpi=300)
plt.show()

# %%
# Plot renewables_df
# Preview
renewables_df.head()
# Out:
#       Year  Hydro  Wind  Bioenergy  Solar  Yearly Totals  Hydro Cumulative  \
# 0  1994–95  16239     7        723     19          16988             16239
# 1  1995–96  15731     7        928     23          16689             31970
# 2  1996–97  16852     7        965     28          17852             48822
# 3  1997–98  15733     8       1029     34          16804             64555
# 4  1998–99  16563    28       1133     38          17762             81118
#
#    Wind Cumulative  Bioenergy Cumulative  Solar Cumulative
# 0                7                   723                19
# 1               14                  1651                42
# 2               21                  2616                70
# 3               29                  3645               104
# 4               57                  4778               142

# %%
# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Data
plotdata_7 = pd.DataFrame({
    "Hydro":[16239, 15731, 16852, 15733, 16563, 16720, 16933, 16054, 16490, 16331, 15612, 16029, 14517, 12057, 11869, 
             13549, 16807, 14083, 18270, 18421, 13445, 15318, 16285, 16021, 15967, 15150],
    "Wind":[7, 7, 7, 8, 28, 58, 210, 364, 703, 705, 885, 1713, 2611, 3093, 3824, 5052, 6085, 6970, 7960, 10252, 11467, 
            12200, 12597, 15174, 17712, 20396],
    "Bioenergy":[723, 928, 965, 1029, 1133, 1134, 645, 950, 1584, 1800, 3830, 3911, 3953, 4596, 2795, 2777, 2102, 3044, 
                 3144, 3499, 3592, 3790, 3501, 3518, 3496, 3352],
    "Solar":[19, 23, 28, 34, 38, 44, 50, 58, 58, 69, 78, 91, 105, 123, 156, 425, 1531, 2559, 3827, 4417, 5532, 6839, 
             8072, 9930, 14849, 21033]
    }, 
    index=renewables_df['Year'])

# Figure
plotdata_7.plot(figsize=(15,5), kind="bar", stacked=True, alpha=0.9,
             ).legend(
            loc='upper right', ncol=1, title="Energy source")
plt.plot(renewables_df['Year'], renewables_df['Yearly Totals'], color="purple", markersize='3', 
         linewidth=2)

plt.title("Renewable energy use by fuel-type, 1994–2020", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Gigawatt Hours", fontdict = font_2)

# Style
matplotlib.style.use('default')

# Grid
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', 
                       alpha=0.1, linestyle='--', linewidth=1)

# Aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show/save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/australian-energy/Images/renewables.png", 
           transparent=False, dpi=300)
plt.show()

# %%
# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Data
plt.figure(figsize=(15,5))
plt.plot(renewables_df['Year'], renewables_df['Hydro Cumulative'], color="blue", label='Hydro', markersize='7', 
         linewidth=2)
plt.plot(renewables_df['Year'], renewables_df['Wind Cumulative'], color="orange", label='Wind', markersize='7', 
         linewidth=2)
plt.plot(renewables_df['Year'], renewables_df['Bioenergy Cumulative'], color="red", label='Bioenergy', markersize='7', 
         linewidth=2)
plt.plot(renewables_df['Year'], renewables_df['Solar Cumulative'], color="green", label='Solar', markersize='7', 
         linewidth=2)

plt.legend(title='Energy source', loc='upper right', ncol=1)

# Ticks
plt.xticks((renewables_df['Year'])[::5
                                ], rotation=25)

plt.title("Cumulative renewable energy use by energy source, 1974–2020", fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Gigawatt Hours", fontdict = font_2)

# Style
matplotlib.style.use('default')

# Grid
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', 
                       alpha=0.1, linestyle='--', linewidth=1)

# Aesthetics
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.tight_layout()

# Show/save
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/australian-energy/Images/cumulative_renewables.png", 
            transparent=False, dpi=300)
plt.show()
