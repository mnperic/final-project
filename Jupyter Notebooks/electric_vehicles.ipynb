# %%
# Import dependencies and setup

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as matplotlib

# %%
# Read .csv files and store as DataFrame

aus_ev_path = "../Resources/2019_aus_ev_sales.csv"
aus_ev_df = pd.read_csv(aus_ev_path)

state_ev_path = "../Resources/2019_aus_state_ev_sales.csv"
state_ev_df = pd.read_csv(state_ev_path)

charging_stations_path = "../Resources/2019_aus_state_charging_stations.csv"
charging_stations_df = pd.read_csv(charging_stations_path)

# %%
# Preview aus_ev_df (sales no. of electric/hybrid vs. petrol vehicles, 2011–2019)

aus_ev_df
# Out:
#    year  EV_PHEV  total_vehicles    EV%
# 0  2019     6718         1062867  0.600
# 1  2018     2216         1153111  0.200
# 2  2017     2287         1189116  0.190
# 3  2016     1369         1178133  0.120
# 4  2015     1771         1155408  0.150
# 5  2014     1322         1113224  0.120
# 6  2013      293         1136227  0.026
# 7  2012      253         1112030  0.023
# 8  2011       49         1008437  0.005

# %%
# Statistical analysis on aus_ev_df

total_ev_sales = aus_ev_df['EV_PHEV'].sum()
total_ev_sales = 16278

total_petrol_sales = aus_ev_df['total_vehicles'].sum()
total_petrol_sales = 10108553

# %%
# Calculate cumulative EV_PHEV + cumulative total_vehicles sales and save to DataFrame

aus_ev_df['cumulative_EV_PHEV'] = aus_ev_df['EV_PHEV'].cumsum()
aus_ev_df['cumulative_total_vehicles'] = aus_ev_df['total_vehicles'].cumsum()
aus_ev_df = aus_ev_df.sort_values(by=['cumulative_EV_PHEV'], ascending=False)
aus_ev_df
# Out:
#    year  EV_PHEV  total_vehicles    EV%  cumulative_EV_PHEV  \
# 8  2011       49         1008437  0.005               16278
# 7  2012      253         1112030  0.023               16229
# 6  2013      293         1136227  0.026               15976
# 5  2014     1322         1113224  0.120               15683
# 4  2015     1771         1155408  0.150               14361
# 3  2016     1369         1178133  0.120               12590
# 2  2017     2287         1189116  0.190               11221
# 1  2018     2216         1153111  0.200                8934
# 0  2019     6718         1062867  0.600                6718
#
#    cumulative_total_vehicles
# 8                   10108553
# 7                    9100116
# 6                    7988086
# 5                    6851859
# 4                    5738635
# 3                    4583227
# 2                    3405094
# 1                    2215978
# 0                    1062867

# %%
# Plot bar graph - Total EV/PHEV

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.bar(aus_ev_df['year'], aus_ev_df['EV_PHEV'], width=0.75, color='blue', alpha=0.5)

# Labels
plt.title("Total number of Electric (EV) and Plug-in Hybrid (PHEV) vehicles sold in Australia, 2011–2019", 
          fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Total sold", fontdict = font_2)

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

# Ticks
plt.xticks(x)

plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/final-project/Images/Electric Vehicles/ev_phev_sold.png", 
           transparent=False, dpi=300)
plt.show()

# %%
# Preview state_ev_df (no. of EV/Hybrid vehicles sold per state [per 10,000 vehicles sold])

state_ev_df
# Out:
#   State  EV_per_10000
# 0   NSW            10
# 1   VIC             9
# 2   QLD             7
# 3    SA            21
# 4    WA             8
# 5   TAS             3
# 6    NT             1
# 7   ACT            21

# %%
# Statistical analysis on aus_state_ev_df, add to DataFrame

aus_per_10000 = state_ev_df['EV_per_10000'].sum()
aus_per_10000 = 80

# %%
# Plot bar graph - Total EV/PHEV per state, per 10,000

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.bar(state_ev_df['State'], state_ev_df['EV_per_10000'], width=0.75, color='blue', alpha=0.5)

# Labels
plt.title("Total number of Electric (EV) and Plug-in Hybrid (PHEV) vehicles sold per state (per 10,000 vehicles), 2019", 
          fontdict = font_1)
plt.xlabel("Year", fontdict = font_2)
plt.ylabel("Total sold", fontdict = font_2)

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/final-project/Images/Electric Vehicles/ev_phev_sold_per_state.png", 
          transparent=False, dpi=300)
plt.show()

# %%
# Preview charging_stations_df (no. of EV charging stations per state)

charging_stations_df
# Out:
#   state  charging_stations
# 0   NSW                161
# 1   VIC                216
# 2   QLD                162
# 3    SA                 76
# 4    WA                122
# 5   TAS                 21
# 6    NT                  5
# 7   ACT                 20

# %%
# Statistical analysis on charging_stations_df

aus_charging_stations = charging_stations_df['charging_stations'].sum()
aus_charging_stations = 783

# %%
# Plot bar graph - Total EV/PHEV per state, per 10,000

# Font families
font_1 = {'family':'helvetica','color':'black','size':16}
font_2 = {'family':'helvetica','color':'black','size':12}

# Plot
plt.figure(figsize=(15,5))
plt.bar(charging_stations_df['state'], charging_stations_df['charging_stations'], width=0.75, color='blue', alpha=0.5)

# Labels
plt.title("Total number of charging stations per state, 2019", 
          fontdict = font_1)
plt.xlabel("State", fontdict = font_2)
plt.ylabel("Charging stations", fontdict = font_2)

# Aesthetics
matplotlib.pyplot.grid(visible=True, which='both', axis='both', color='blue', alpha=0.1, linestyle='--', linewidth=1)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.tight_layout()

# Save and show
plt.savefig("/Users/minoperic/Data Analytics/Data Investigations/final-project/Images/Electric Vehicles/charging_stations_per_state.png", 
          transparent=False, dpi=300)
plt.show()
