# %%
# Import dependencies and setup

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as matplotlib
import matplotlib.dates as matplotlibdates
import plotly.express as px
import plotly
import plotly.io as pio

# %%
# Read .csv files and store as DataFrame

aus_ev_path = "Resources/aus_ev_sales.csv"
aus_ev_df = pd.read_csv(aus_ev_path)

state_ev_path = "Resources/aus_state_ev_sales.csv"
state_ev_df = pd.read_csv(state_ev_path)

global_ev_path = "Resources/global_ev_sales.csv"
global_ev_df = pd.read_csv(global_ev_path)

charging_stations_path = "Resources/aus_state_charging_stations.csv"
charging_stations_df = pd.read_csv(charging_stations_path)

# %%
# Preview aus_ev_df (sales no. of electric/hybrid vs. petrol vehicles, 2011–2019)

aus_ev_df
# Out:
#    year  EV_PHEV  total_vehicles    EV%
# 0  2019     6718         1062867  0.600
# 1  2018     2216         1153111  0.200
# 2  2017     2287         1189116  0.190
# 3  2016     1369         1178133  0.120
# 4  2015     1771         1155408  0.150
# 5  2014     1322         1113224  0.120
# 6  2013      293         1136227  0.026
# 7  2012      253         1112030  0.023
# 8  2011       49         1008437  0.005

# %%
# Statistical analysis on aus_ev_df

total_ev_sales = aus_ev_df['EV_PHEV'].sum()
total_ev_sales = 16278

total_petrol_sales = aus_ev_df['total_vehicles'].sum()
total_petrol_sales = 10108553

# %%
# Calculate cumulative EV_PHEV + cumulative total_vehicles sales and save to DataFrame

aus_ev_df['cumulative_EV_PHEV'] = aus_ev_df['EV_PHEV'].cumsum()
aus_ev_df['cumulative_total_vehicles'] = aus_ev_df['total_vehicles'].cumsum()
aus_ev_df = aus_ev_df.sort_values(by=['cumulative_EV_PHEV'], ascending=False)
aus_ev_df
# Out:
#    year  EV_PHEV  total_vehicles    EV%  cumulative_EV_PHEV  \
# 0  2019     6718         1062867  0.600               16278
# 1  2018     2216         1153111  0.200                9560
# 2  2017     2287         1189116  0.190                7344
# 3  2016     1369         1178133  0.120                5057
# 4  2015     1771         1155408  0.150                3688
# 5  2014     1322         1113224  0.120                1917
# 6  2013      293         1136227  0.026                 595
# 7  2012      253         1112030  0.023                 302
# 8  2011       49         1008437  0.005                  49
#
#    cumulative_total_vehicles
# 0                   10108553
# 1                    9045686
# 2                    7892575
# 3                    6703459
# 4                    5525326
# 5                    4369918
# 6                    3256694
# 7                    2120467
# 8                    1008437

# %%
# Plot bar graph

x = aus_ev_df['year']
y = aus_ev_df['EV_PHEV']

fig = px.bar(x=x, y=y, labels=dict(x="Year", y="# sold"),
             title='Total number of Electric (EV) and Plug-in Hybrid (PHEV) vehicles sold in Australia')

fig.update_layout(
    font_family="Helvetica",
    font_color="black",
    title_font_family="Helvetica",
    title_font_color="black",
    legend_title_font_color="black")

fig.layout.template = 'presentation'

fig.update_xaxes(title_font_family="Helvetica")
plotly.offline.plot(fig, filename='/Users/minoperic/Data Analytics/Data Investigations/australian-electric-vehicle-sales/fig_1.html')
fig.show()
# Out:
# <div>                            <div id="597d7343-88ed-4102-ae07-acae01567a23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("597d7343-88ed-4102-ae07-acae01567a23")) {                    Plotly.newPlot(                        "597d7343-88ed-4102-ae07-acae01567a23",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}<br># sold=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2019,2018,2017,2016,2015,2014,2013,2012,2011],"xaxis":"x","y":[6718,2216,2287,1369,1771,1322,293,253,49],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"table"}]},"layout":{"font":{"size":18},"xaxis":{"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Year","font":{"family":"Helvetica"}}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"# sold"}},"legend":{"tracegroupgap":0,"title":{"font":{"color":"black"}}},"title":{"text":"Total number of Electric (EV) and Plug-in Hybrid (PHEV) vehicles sold in Australia","font":{"family":"Helvetica","color":"black"}},"barmode":"relative","font":{"family":"Helvetica","color":"black"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('597d7343-88ed-4102-ae07-acae01567a23');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
# Plot bar graph

x = aus_ev_df['year']
y = aus_ev_df['total_vehicles']

fig = px.bar(x=x, y=y, labels=dict(x="Year", y="# sold"),
             title='Total number of vehicles sold in Australia')

fig.update_layout(
    font_family="Helvetica",
    font_color="black",
    title_font_family="Helvetica",
    title_font_color="black",
    legend_title_font_color="black")

fig.layout.template = 'presentation'

fig.update_xaxes(title_font_family="Helvetica")
plotly.offline.plot(fig, filename='/Users/minoperic/Data Analytics/Data Investigations/australian-electric-vehicle-sales/fig_2.html')
fig.show()
# Out:
# <div>                            <div id="27db86ee-3e85-4282-8460-38381c08505d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("27db86ee-3e85-4282-8460-38381c08505d")) {                    Plotly.newPlot(                        "27db86ee-3e85-4282-8460-38381c08505d",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}<br># sold=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2019,2018,2017,2016,2015,2014,2013,2012,2011],"xaxis":"x","y":[1062867,1153111,1189116,1178133,1155408,1113224,1136227,1112030,1008437],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"table"}]},"layout":{"font":{"size":18},"xaxis":{"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Year","font":{"family":"Helvetica"}}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"# sold"}},"legend":{"tracegroupgap":0,"title":{"font":{"color":"black"}}},"title":{"text":"Total number of vehicles sold in Australia","font":{"family":"Helvetica","color":"black"}},"barmode":"relative","font":{"family":"Helvetica","color":"black"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('27db86ee-3e85-4282-8460-38381c08505d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
# Preview state_ev_df (no. of EV/Hybrid vehicles sold per state [per 10,000 vehicles sold])

state_ev_df
# Out:
#   State  EV_per_10000
# 0   NSW            10
# 1   VIC             9
# 2   QLD             7
# 3    SA            21
# 4    WA             8
# 5   TAS             3
# 6    NT             1
# 7   ACT            21

# %%
# Statistical analysis on aus_state_ev_df, add to DataFrame

aus_per_10000 = state_ev_df['EV_per_10000'].sum()
aus_per_10000 = 80

# %%
# Plot bar graph

x = state_ev_df['State']
y = state_ev_df['EV_per_10000']

fig = px.bar(x=x, y=y, labels=dict(x="State", y="# vehicles sold"),
             title='Total number of EV/PHEV vehicles sold per state (per 10,000 vehicles)')

fig.update_layout(
    font_family="Helvetica",
    font_color="black",
    title_font_family="Helvetica",
    title_font_color="black",
    legend_title_font_color="black")

fig.layout.template = 'presentation'

fig.update_xaxes(title_font_family="Helvetica")
plotly.offline.plot(fig, filename='/Users/minoperic/Data Analytics/Data Investigations/australian-electric-vehicle-sales/fig_3.html')
fig.show()
# Out:
# <div>                            <div id="9e4808be-ed9f-4dfb-a22c-cf2a7368957f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e4808be-ed9f-4dfb-a22c-cf2a7368957f")) {                    Plotly.newPlot(                        "9e4808be-ed9f-4dfb-a22c-cf2a7368957f",                        [{"alignmentgroup":"True","hovertemplate":"State=%{x}<br># vehicles sold=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["NSW","VIC","QLD","SA","WA","TAS","NT","ACT"],"xaxis":"x","y":[10,9,7,21,8,3,1,21],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"table"}]},"layout":{"font":{"size":18},"xaxis":{"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"State","font":{"family":"Helvetica"}}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"# vehicles sold"}},"legend":{"tracegroupgap":0,"title":{"font":{"color":"black"}}},"title":{"text":"Total number of EV/PHEV vehicles sold per state (per 10,000 vehicles)","font":{"family":"Helvetica","color":"black"}},"barmode":"relative","font":{"family":"Helvetica","color":"black"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('9e4808be-ed9f-4dfb-a22c-cf2a7368957f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
# Preview global_ev_df (total % of EV sold globally – 2019)

global_ev_df
# Out:
#        country percent
# 0       Norway   10.7%
# 1  Netherlands    1.7%
# 2        China   0.94%
# 3       Sweden    0.6%
# 4          USA   0.45%
# 5    Australia    0.2%

# %%
# Plot bar graph

x = global_ev_df['country']
y = global_ev_df['percent']

fig = px.bar(x=x, y=y, labels=dict(x="Country", y="# sold (%)"),
             title='Total percentage of new electric vehicle sales, 2020')

fig.update_layout(
    font_family="Helvetica",
    font_color="black",
    title_font_family="Helvetica",
    title_font_color="black",
    legend_title_font_color="black")

fig.layout.template = 'presentation'

fig.update_xaxes(title_font_family="Helvetica")
plotly.offline.plot(fig, filename='/Users/minoperic/Data Analytics/Data Investigations/australian-electric-vehicle-sales/fig_4.html')
fig.show()
# Out:
# <div>                            <div id="d8e576f2-bbc4-4e81-86a8-795b42bb7026" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d8e576f2-bbc4-4e81-86a8-795b42bb7026")) {                    Plotly.newPlot(                        "d8e576f2-bbc4-4e81-86a8-795b42bb7026",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br># sold (%)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Norway","Netherlands","China","Sweden","USA","Australia"],"xaxis":"x","y":["10.7%","1.7%","0.94%","0.6%","0.45%","0.2%"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"table"}]},"layout":{"font":{"size":18},"xaxis":{"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"Country","font":{"family":"Helvetica"}}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"# sold (%)"}},"legend":{"tracegroupgap":0,"title":{"font":{"color":"black"}}},"title":{"text":"Total percentage of new electric vehicle sales, 2020","font":{"family":"Helvetica","color":"black"}},"barmode":"relative","font":{"family":"Helvetica","color":"black"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('d8e576f2-bbc4-4e81-86a8-795b42bb7026');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
# Preview charging_stations_df (no. of EV charging stations per state)

charging_stations_df
# Out:
#   state  charging_stations
# 0   NSW                161
# 1   VIC                216
# 2   QLD                162
# 3    SA                 76
# 4    WA                122
# 5   TAS                 21
# 6    NT                  5
# 7   ACT                 20

# %%
# Statistical analysis on charging_stations_df

aus_charging_stations = charging_stations_df['charging_stations'].sum()
aus_charging_stations = 783

# %%
# Plot bar graph

x = charging_stations_df['state']
y = charging_stations_df['charging_stations']

fig = px.bar(x=x, y=y, labels=dict(x="State", y="# charging stations"),
             title='Number of charging stations per state, 2020')

fig.update_layout(
    font_family="Helvetica",
    font_color="black",
    title_font_family="Helvetica",
    title_font_color="black",
    legend_title_font_color="black")

fig.layout.template = 'presentation'

fig.update_xaxes(title_font_family="Helvetica")
plotly.offline.plot(fig, filename='/Users/minoperic/Data Analytics/Data Investigations/australian-electric-vehicle-sales/fig_5.html')
fig.show()
# Out:
# <div>                            <div id="4162b18b-3299-4d01-8372-d98efd8ccf25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4162b18b-3299-4d01-8372-d98efd8ccf25")) {                    Plotly.newPlot(                        "4162b18b-3299-4d01-8372-d98efd8ccf25",                        [{"alignmentgroup":"True","hovertemplate":"State=%{x}<br># charging stations=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["NSW","VIC","QLD","SA","WA","TAS","NT","ACT"],"xaxis":"x","y":[161,216,162,76,122,21,5,20],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"table"}]},"layout":{"font":{"size":18},"xaxis":{"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"xaxis":{"anchor":"y","domain":[0.0,1.0],"title":{"text":"State","font":{"family":"Helvetica"}}},"yaxis":{"anchor":"x","domain":[0.0,1.0],"title":{"text":"# charging stations"}},"legend":{"tracegroupgap":0,"title":{"font":{"color":"black"}}},"title":{"text":"Number of charging stations per state, 2020","font":{"family":"Helvetica","color":"black"}},"barmode":"relative","font":{"family":"Helvetica","color":"black"}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('4162b18b-3299-4d01-8372-d98efd8ccf25');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>
